# %% [markdown]
# ![AIwarmups.png](attachment:5a91dcde-111c-4e04-8730-dd9c59590ee4.png)
#
# On github @ [Github Docu](https://github.tools.sap/D061192/hackathonnotebooks)

# %% [markdown]
# # Prerequisites
#
# You have..
#
# - Access to the BTP Control Center's Landscape "**Canary - Public Cloud [Feature Set B]**"  @ https://controlcenter.ondemand.com/index.html
# - install the [BTP CLI](http://developers.sap.com/tutorials/cp-sapcp-getstarted..html)
# - install the [Joule CLI](https://help.sap.com/docs/joule/service-guide/install-and-update-command-line-interface?locale=en-US&q=Create%20Joule%20Subscription%20and%20Instance)

# %% [markdown]
# # Choices.. Deploying using CLI or GUI
#
# You can deploy Joule on BTP either.
#
# # Option 1: deploying Joule on BTP with a Web browser and ~ 140 clicks..
#
# - **this clickpath is already out of date. So I recommed using the BTP CLI instead..**
# - while this video is currently valid, it will doubtless  be out of date (and not useful) very soon
# - <a href="https://video.sap.com/media/t/1_gbzb3tp0" target="_blank" >
# https://video.sap.com/media/t/1_gbzb3tp0
# </a>
#
# ![jouleonbtpclickpath20240619.png](attachment:24d3b899-5c6a-4ef2-894d-c4d6ee0aa0ad.png)

# %% [markdown]
# # Option 2: deploying Joule on BTP with the BTP CLI, directly in Jupyter
#
#  See neighbouring JouleScriptsREADME ("Installing Joule on BTP Scripted") for the journey..
